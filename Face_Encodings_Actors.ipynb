# %% [markdown]
# Installing Libraries

# %%
# !pip install face_recognition
# !pip install moviepy
# !pip install ffmpeg
# Out:
# ...
#      |████████████████████████████████| 100.1 MB 9.0 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=24fbd8f60c4e8b0517673eaf5cca0a78182c58300adb78a14dacf558eaf6d8dd
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=29351569866cbb45d8c576c7cf7b6863f8db8fec0a892bb54204f56244f4524b
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
# Successfully built ffmpeg
# ...

# %%
from imutils import paths
import face_recognition
import pickle
import cv2
import os
import moviepy.editor as mp
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %% [markdown]
# Getting paths of each file in the folder
#
# Images here contains my data (folders of various persons)

# %%
imagePaths = list(paths.list_images('/content/drive/MyDrive/LinkedIn/Welcome/Images'))
knownEncodings = []
knownNames = []

# %% [markdown]
# Getting face encoding for image of each actor and craeting a dictionary with respeactive encodings and name of the actor.
#
# Incase the library is unable to find a face in the image, we discard that image.

# %%
# %%timeit
for (i, imagePath) in enumerate(imagePaths):
    
    # extract the person name from the image path
    name = imagePath.split(os.path.sep)[-2]
    
    # load the input image and convert it from BGR (OpenCV ordering)
    # to dlib ordering (RGB)
    image = face_recognition.load_image_file(imagePath)
  
    # compute the facial embedding for the face
    encodings = face_recognition.face_encodings(image)
    if len(encodings) == 0:
      print("No faces were found.")
    else:
      first_face_encoding = encodings[0]

    # loop over the encodings
    for encoding in encodings:
        knownEncodings.append(encoding)
        knownNames.append(name)
# Out:
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# No faces were found.
# ...

# %% [markdown]
# Saving encodings along with their names in dictionary data

# %%
data = {"encodings": knownEncodings, "names": knownNames}

# %%
data
# Out:
# {'encodings': [array([-0.15159187,  0.01270688,  0.04554271,  0.00241059, -0.04916245,
#          -0.07270584, -0.07997227, -0.10198756,  0.18739364, -0.12023157,
#           0.15427694, -0.08455692, -0.29835933,  0.02902232, -0.18757747,
#           0.13384756, -0.20527869, -0.14756668,  0.02126887, -0.030699  ,
#           0.16436578, -0.00525564, -0.0053422 ,  0.16554698, -0.11964826,
#          -0.37399796, -0.10281783, -0.16483033, -0.04779041, -0.09421918,
#          -0.0727614 ,  0.03769969, -0.23505913, -0.00881558, -0.01612647,
#           0.07046025,  0.10438509, -0.0974323 ,  0.16649197,  0.00696865,
#          -0.26480091, -0.08170536,  0.1686855 ,  0.19479257,  0.15814635,
#           0.03916106, -0.04599536, -0.06478725,  0.18957503, -0.28574222,
#           0.02556781,  0.20155573,  0.10713759,  0.09567642,  0.11398245,
#          -0.23695308,  0.04212714,  0.03947321, -0.17176838,  0.06276508,
# ...

# %% [markdown]
# Saving the data using pickle library.

# %%
import pickle
pickle.dump(data, open('/content/drive/MyDrive/LinkedIn/Welcome/welcome_data.pkl', 'wb'))
